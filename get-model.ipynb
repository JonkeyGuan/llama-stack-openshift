# %%
# !hfd deepseek-ai/DeepSeek-R1-Distill-Qwen-32B --exclude .bin --tool aria2c -x 8

# %%
# !hfd unsloth/DeepSeek-R1-0528-Qwen3-8B-unsloth-bnb-4bit --exclude .bin --tool aria2c -x 8

# %%
# !hfd deepseek-ai/DeepSeek-R1-0528-Qwen3-8B --exclude .bin --tool aria2c -x 8

# %%
# !hfd ibm-granite/granite-3.2-8b-instruct --exclude .bin --tool aria2c -x 8
# Out:
# ...
# Test GIT_REFS_URL: https://huggingface.co/ibm-granite/granite-3.2-8b-instruct/info/refs?service=git-upload-pack
# git clone https://huggingface.co/ibm-granite/granite-3.2-8b-instruct
# Cloning into 'granite-3.2-8b-instruct'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 34 (delta 9), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (34/34), 1.19 MiB | 2.44 MiB/s, done.
#
# Start Downloading lfs files, bash script:
# aria2c -x 8 -s 8 -k 1M -c "https://huggingface.co/ibm-granite/granite-3.2-8b-instruct/resolve/main/model-00001-of-00004.safetensors" -d "." -o "model-00001-of-00004.safetensors"
# aria2c -x 8 -s 8 -k 1M -c "https://huggingface.co/ibm-granite/granite-3.2-8b-instruct/resolve/main/model-00002-of-00004.safetensors" -d "." -o "model-00002-of-00004.safetensors"
# ...

# %%
# !hfd RedHatAI/Qwen3-32B-FP8-dynamic --exclude .bin --tool aria2c -x 8
# Out:
# ...
# Test GIT_REFS_URL: https://huggingface.co/RedHatAI/Qwen3-32B-FP8-dynamic/info/refs?service=git-upload-pack
# git clone https://huggingface.co/RedHatAI/Qwen3-32B-FP8-dynamic
# Cloning into 'Qwen3-32B-FP8-dynamic'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 41 (delta 11), reused 0 (delta 0), pack-reused 3 (from 1)
# Unpacking objects: 100% (41/41), 1.73 MiB | 4.14 MiB/s, done.
#
# Start Downloading lfs files, bash script:
# aria2c -x 8 -s 8 -k 1M -c "https://huggingface.co/RedHatAI/Qwen3-32B-FP8-dynamic/resolve/main/model-00001-of-00007.safetensors" -d "." -o "model-00001-of-00007.safetensors"
# aria2c -x 8 -s 8 -k 1M -c "https://huggingface.co/RedHatAI/Qwen3-32B-FP8-dynamic/resolve/main/model-00002-of-00007.safetensors" -d "." -o "model-00002-of-00007.safetensors"
# ...
